# %% [markdown]
# <a href="https://colab.research.google.com/github/sankit601/python-project-datasets/blob/main/worldpopulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#in this project will try to analyze the world_population data

# %%
#firststep importing pandas
import pandas as pd

# %%
#importing data
wp=pd.read_csv('https://raw.githubusercontent.com/sankit601/python-project-datasets/main/Population%20Data.csv')
wp
#wp is my variable name for world population dataset
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
#checking first and  last 10 rows of our datasets
#first 10 rows
wp.head(10)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 7                   Arab World          ARB  Population, total    SP.POP.TOTL
# 8         United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 9                    Argentina          ARG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# ...

# %%
#checking last 10 Rows
wp.tail(10)
# Out:
#               Country Name Country Code     Indicator Name Indicator Code  \
# 256  Virgin Islands (U.S.)          VIR  Population, total    SP.POP.TOTL
# 257                Vietnam          VNM  Population, total    SP.POP.TOTL
# 258                Vanuatu          VUT  Population, total    SP.POP.TOTL
# 259                  World          WLD  Population, total    SP.POP.TOTL
# 260                  Samoa          WSM  Population, total    SP.POP.TOTL
# 261                 Kosovo          XKX  Population, total    SP.POP.TOTL
# 262            Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 263           South Africa          ZAF  Population, total    SP.POP.TOTL
# 264                 Zambia          ZMB  Population, total    SP.POP.TOTL
# 265               Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 256  3.250000e+04  3.430000e+04  3.500000e+04  3.980000e+04  4.080000e+04
# ...

# %%
wp.sample(20)
# Out:
#                                           Country Name Country Code  \
# 11                                      American Samoa          ASM
# 106                                          Indonesia          IDN
# 223                                             Sweden          SWE
# 196                                 West Bank and Gaza          PSE
# 68                                           Euro area          EMU
# 259                                              World          WLD
# 202                                 Russian Federation          RUS
# 56                                            Djibouti          DJI
# 178                                              Nepal          NPL
# 161  Middle East & North Africa (excluding high inc...          MNA
# 37                                         Switzerland          CHE
# 18                                               Benin          BEN
# 222                                           Slovenia          SVN
# ...

# %%
#understanding the dataset::checking the column name
wp.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
#understanding the dataset type
wp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
#population dataset has 266 rows and 66 columns; 
#4 columns are object and rest others are float type

# %%
wp.shape
# Out:
# (266, 66)

# %%
#checking null values in dataset
wp.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2017              1
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# Length: 66, dtype: int64

# %%
##checking total null values in dataset

# %%
#we have total92 null values in dataset
wp.isnull().sum().sum()
# Out:
# 92

# %%
#dealing with null values;
#option1: we can leave it as it is as it is not going make much difference
#option2: we can delete the columns
#option3: we can change the null values to 0

# %%
# we will go with option 3

# %%
wp.fillna(0,inplace=True)
# Out:
# 0

# %%
#checking for null values again
wp.isnull().sum().sum()
# Out:
# 0

# %%
#checking for duplicates in dataset
(wp.duplicated()).value_counts()
# Out:
# False    266
# dtype: int64

# %%
#we dont have any duplicate records in our dataset

# %%
#sorting the data country wise alphbatically
wp.sort_values(['Country Name'],ascending=True)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 2                    Afghanistan          AFG  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 5                        Albania          ALB  Population, total
# 60                       Algeria          DZA  Population, total
# ..                           ...          ...                ...
# 196           West Bank and Gaza          PSE  Population, total
# 259                        World          WLD  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code          1960          1961          1962          1963  \
# 2      SP.POP.TOTL  8.622466e+06  8.790140e+06  8.969047e+06  9.157465e+06
# ...

# %%
#checking the population change from 1960 to 2021
#creating a new column name 'population_change
wp['population_change']=wp['2021']-wp['1960']

# %%
wp
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
#creating a column name population_change_percent with % values for better undestanding of the data
wp['population_change_percent']=(wp['population_change']/wp['population_change'].sum())*100
wp.sample(10)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 18                       Benin          BEN  Population, total    SP.POP.TOTL
# 45                    Colombia          COL  Population, total    SP.POP.TOTL
# 225  Sint Maarten (Dutch part)          SXM  Population, total    SP.POP.TOTL
# 58                     Denmark          DNK  Population, total    SP.POP.TOTL
# 77                      France          FRA  Population, total    SP.POP.TOTL
# 167                  Mauritius          MUS  Population, total    SP.POP.TOTL
# 127                     Kuwait          KWT  Population, total    SP.POP.TOTL
# 265                   Zimbabwe          ZWE  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 185                     Panama          PAN  Population, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964        1965  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-cb3b17fe929f> in <module>
#       1 for x in wp['population_change']:
# ----> 2   x=x.max()
#       3   print(x)
#
# AttributeError: 'float' object has no attribute 'max'

# %%
maxpop(wp['population_change'])
# Out:
# [51929.0]

# %%
import numpy as np

# %%
#countries with population more than 10000000 in 2021
wp1=wp[wp['2021']>10000000]
wp1
# Out:
#                     Country Name Country Code     Indicator Name  \
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# 7                     Arab World          ARB  Population, total
# ..                           ...          ...                ...
# 259                        World          WLD  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code          1960          1961          1962          1963  \
# 1      SP.POP.TOTL  1.306926e+08  1.341692e+08  1.378356e+08  1.416305e+08
# ...

# %%
#BRICS countries data analysis
wp_brics= wp[wp['Country Name'].isin(['Brazil','Russia','India','China','South Africa'])]
wp_brics
# Out:
#      Country Name Country Code     Indicator Name Indicator Code         1960  \
# 29         Brazil          BRA  Population, total    SP.POP.TOTL   73092515.0
# 40          China          CHN  Population, total    SP.POP.TOTL  667070000.0
# 109         India          IND  Population, total    SP.POP.TOTL  445954579.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL   16520441.0
#
#             1961         1962         1963         1964         1965  ...  \
# 29    75330008.0   77599218.0   79915555.0   82262794.0   84623747.0  ...
# 40   660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
# 109  456351876.0  467024193.0  477933619.0  489059309.0  500114346.0  ...
# 263   16989464.0   17503133.0   18042215.0   18603097.0   19187194.0  ...
#
#              2014          2015          2016          2017          2018  \
# 29   2.034596e+08  2.051882e+08  2.068596e+08  2.085050e+08  2.101666e+08
# ...

# %%
#sum of total brics population in 2021
wp_brics['total_population_2021']=wp_brics['2021'].sum()
# Out:
# <ipython-input-103-1eedb435d838>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wp_brics['total_population_2021']=wp_brics['2021'].sum()

# %%
wp_brics
# Out:
#      Country Name Country Code     Indicator Name Indicator Code         1960  \
# 29         Brazil          BRA  Population, total    SP.POP.TOTL   73092515.0
# 40          China          CHN  Population, total    SP.POP.TOTL  667070000.0
# 109         India          IND  Population, total    SP.POP.TOTL  445954579.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL   16520441.0
#
#             1961         1962         1963         1964         1965  ...  \
# 29    75330008.0   77599218.0   79915555.0   82262794.0   84623747.0  ...
# 40   660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
# 109  456351876.0  467024193.0  477933619.0  489059309.0  500114346.0  ...
# 263   16989464.0   17503133.0   18042215.0   18603097.0   19187194.0  ...
#
#              2015          2016          2017          2018          2019  \
# 29   2.051882e+08  2.068596e+08  2.085050e+08  2.101666e+08  2.117829e+08
# ...

# %%
#reseting the index
wp_brics.reset_index(drop='index')
# Out:
#    Country Name Country Code     Indicator Name Indicator Code         1960  \
# 0        Brazil          BRA  Population, total    SP.POP.TOTL   73092515.0
# 1         China          CHN  Population, total    SP.POP.TOTL  667070000.0
# 2         India          IND  Population, total    SP.POP.TOTL  445954579.0
# 3  South Africa          ZAF  Population, total    SP.POP.TOTL   16520441.0
#
#           1961         1962         1963         1964         1965  ...  \
# 0   75330008.0   77599218.0   79915555.0   82262794.0   84623747.0  ...
# 1  660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
# 2  456351876.0  467024193.0  477933619.0  489059309.0  500114346.0  ...
# 3   16989464.0   17503133.0   18042215.0   18603097.0   19187194.0  ...
#
#            2015          2016          2017          2018          2019  \
# 0  2.051882e+08  2.068596e+08  2.085050e+08  2.101666e+08  2.117829e+08
# 1  1.379860e+09  1.387790e+09  1.396215e+09  1.402760e+09  1.407745e+09
# ...

# %%
total_brics_population=wp_brics.sum()
total_brics_population.tail(7)
# Out:
# 2018                          3039269533.0
# 2019                          3060726983.0
# 2020                          3079485358.0
# 2021                          3093642320.0
# population_change             1891004785.0
# population_change_percent         3.471623
# total_population_2021        12374569280.0
# dtype: object
